# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.style.use('seaborn-paper')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# set matplotlib font to Times
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)

# %% [markdown]
# ## Asymmetric mean squared error

# %%
f = plt.figure()

x = np.linspace(-5, 5)
plt.plot(x, (x**2) * ((np.sign(x)) ** 2), 'k', label="alpha=0")
plt.plot(x, (x**2) * ((np.sign(x) + 0.2) ** 2), 'k:', label="alpha=0.2")
plt.plot(x, (x**2) * ((np.sign(x) + 0.4) ** 2), 'k-.', label="alpha=0.4")
plt.plot(x, (x**2) * ((np.sign(x) + 0.6) ** 2), 'k--', label="alpha=0.6")
plt.xlabel('$d_i$', fontsize=13)
plt.ylabel('$c(d_i)$', fontsize=13)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.legend(fontsize=11);

f.savefig("amse-function.pdf", bbox_inches='tight')
