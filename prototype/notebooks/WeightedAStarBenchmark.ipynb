# %% [markdown]
# # PDB 7-8 Weighted A Star: performance analysis

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.style.use('seaborn-paper')

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# set matplotlib font to Times
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)

# %% [markdown]
# ## Data preprocessing

# %%
results = pd.read_csv("/home/vojta/code/fifteen-puzzle/data/experiments/weighted-a-star-benchmark.csv")
results.shape
# Out:
# (651, 9)

# %%
results.head(10)
# Out:
#                             PROCESS_ID  BOARD_ID ALGORITHM_NAME  \
# 0  2019-11-29 00:29:03.533076 PID10380         1             A*
# 1  2019-11-29 00:29:03.533076 PID10380         1             A*
# 2  2019-11-29 00:29:03.533076 PID10380         1             A*
# 3  2019-11-29 00:29:03.533076 PID10380         2             A*
# 4  2019-11-29 00:29:03.533076 PID10380         2             A*
# 5  2019-11-29 00:29:03.533076 PID10380         2             A*
# 6  2019-11-29 00:29:03.533076 PID10380         3             A*
# 7  2019-11-29 00:29:03.533076 PID10380         3             A*
# 8  2019-11-29 00:29:03.533076 PID10380         3             A*
# 9  2019-11-29 00:29:03.533076 PID10380         4             A*
#
#       HEURISTIC_NAME BOARDS_GENERATOR_NAME  RUN_TIME  SOLUTION_COST  \
# 0  PDB[Pat:8;W:1.15]                   RND  0.277251             56
# 1   PDB[Pat:8;W:1.2]                   RND  0.156959             56
# ...

# %%
results["HEURISTIC_NAME"].unique()
# Out:
# array(['PDB[Pat:8;W:1.15]', 'PDB[Pat:8;W:1.2]', 'PDB[Pat:8;W:1.25]'],
#       dtype=object)

# %%
pdb115_results = results[results["HEURISTIC_NAME"] == "PDB[Pat:8;W:1.15]"]
pdb120_results = results[results["HEURISTIC_NAME"] == "PDB[Pat:8;W:1.2]"]
pdb125_results = results[results["HEURISTIC_NAME"] == "PDB[Pat:8;W:1.25]"]

# %%
pdb115_results.describe()
# Out:
#          BOARD_ID    RUN_TIME  SOLUTION_COST  EXPANDED_NODES  \
# count  217.000000  217.000000     217.000000      217.000000
# mean   109.000000    0.241007      52.940092     2556.396313
# std     62.786676    0.278444       5.376656     2933.869929
# min      1.000000    0.002984      26.000000       33.000000
# 25%     55.000000    0.053834      50.000000      611.000000
# 50%    109.000000    0.140331      53.000000     1513.000000
# 75%    163.000000    0.314811      56.000000     3314.000000
# max    217.000000    1.672468      68.000000    17350.000000
#
#        INITIAL_HEURISTIC_PREDICTION
# count                    217.000000
# mean                      52.136866
# std                        5.499888
# min                       27.600000
# 25%                       48.300000
# 50%                       51.750000
# 75%                       56.350000
# max                       69.000000

# %%
pdb120_results.describe()
# Out:
#          BOARD_ID    RUN_TIME  SOLUTION_COST  EXPANDED_NODES  \
# count  217.000000  217.000000     217.000000      217.000000
# mean   109.000000    0.162519      53.548387     1730.603687
# std     62.786676    0.205564       5.520895     2188.190338
# min      1.000000    0.002968      26.000000       33.000000
# 25%     55.000000    0.040946      50.000000      419.000000
# 50%    109.000000    0.095075      54.000000     1056.000000
# 75%    163.000000    0.201152      57.000000     2099.000000
# max    217.000000    1.300879      68.000000    13999.000000
#
#        INITIAL_HEURISTIC_PREDICTION
# count                    217.000000
# mean                      54.403687
# std                        5.739014
# min                       28.800000
# 25%                       50.400000
# 50%                       54.000000
# 75%                       58.800000
# max                       72.000000

# %%
pdb125_results.describe()
# Out:
#          BOARD_ID    RUN_TIME  SOLUTION_COST  EXPANDED_NODES  \
# count  217.000000  217.000000     217.000000      217.000000
# mean   109.000000    0.114063      54.211982     1223.124424
# std     62.786676    0.152248       5.766381     1562.166791
# min      1.000000    0.002958      26.000000       33.000000
# 25%     55.000000    0.028090      51.000000      318.000000
# 50%    109.000000    0.059724      55.000000      663.000000
# 75%    163.000000    0.141049      58.000000     1574.000000
# max    217.000000    1.329821      74.000000    12707.000000
#
#        INITIAL_HEURISTIC_PREDICTION
# count                    217.000000
# mean                      56.670507
# std                        5.978140
# min                       30.000000
# 25%                       52.500000
# 50%                       56.250000
# 75%                       61.250000
# max                       75.000000
